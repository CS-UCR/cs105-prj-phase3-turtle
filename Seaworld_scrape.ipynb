# %%
import requests
from collections import deque
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get('https://www.yelp.com/biz/monterey-bay-aquarium-monterey?osq=Monterey+Bay+Aquarium')
soup = BeautifulSoup(page.content, 'html.parser')


review_date = [] 
review_rating = [] 
review_text = []

# %%
for div in soup.find_all('div',class_='lemon--div__373c0__1mboc arrange-unit__373c0__1piwO arrange-unit-grid-column--8__373c0__2yTAx border-color--default__373c0__2oFDT'):
#         print(div.text,'\n')


        # Get date for review
        if div.find('span',class_="lemon--span__373c0__3997G text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_"):
            print(div.find('span',class_="lemon--span__373c0__3997G text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_").text)
            review_date.append(div.find('span',class_="lemon--span__373c0__3997G text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_").text)
            
        # Find 5 star ratings
        if div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-5__373c0__3kPgP border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
            print(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-5__373c0__3kPgP border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'],'\n')
            review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-5__373c0__3kPgP border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])
            
        # Find 4 star ratings
        if div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-4__373c0__vUL-e border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
            print(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-4__373c0__vUL-e border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'],'\n')
            review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-4__373c0__vUL-e border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])

                
        # Find 3 star ratings
        if div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-3__373c0__28SvJ border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
            print(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-3__373c0__28SvJ border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'],'\n')
            review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-3__373c0__28SvJ border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])

     
        # Find 2 star ratings
        if div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-2__373c0__V6RkM border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
            print(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-2__373c0__V6RkM border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'],'\n')   
            review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-2__373c0__V6RkM border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])

                
        # Find 1 star ratings              
        if div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-1__373c0__3Gyy6 border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
            print(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-1__373c0__3Gyy6 border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'],'\n')
            review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-1__373c0__3Gyy6 border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])
            
        # Get review text
        if div.find('p',class_="lemon--p__373c0__3Qnnj text__373c0__2pB8f comment__373c0__3EKjH text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_"):
            print(div.find('p',class_="lemon--p__373c0__3Qnnj text__373c0__2pB8f comment__373c0__3EKjH text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_").text,'\n')
            review_text.append(div.find('p',class_="lemon--p__373c0__3Qnnj text__373c0__2pB8f comment__373c0__3EKjH text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_").text)
        else: 
            print("BREAKING")
# Out:
# BREAKING
# 2/28/2020
# 5 star rating
#
# Ya know we all went here as a 1st grade field tripTraditions gotta be continuedFishiesFishiesFishiesIts a bit sad that they trap fishes for people to stare at them all day but yeah good service even though food is REALLY EXPENSIVE and not good
#
# 2/25/2020
# 5 star rating
#
# ...

# %%
yelp_link = 'https://www.yelp.com'




for span in soup.find_all('div',class_="lemon--div__373c0__1mboc u-padding-b2 border-color--default__373c0__2oFDT text-align--center__373c0__1l506"):
    print(span.text)
    

index = 20
    
# next_page = "https://www.yelp.com/biz/monterey-bay-aquarium-monterey?osq=Monterey%20Bay%20Aquarium&start={}".format(index)
# print(next_page)
    
# page = requests.get(next_page)
# soup = BeautifulSoup(page.content, 'html.parser')
   

# for span in soup.find_all('div',class_="lemon--div__373c0__1mboc u-padding-b2 border-color--default__373c0__2oFDT text-align--center__373c0__1l506"):
#     print(span.text)
    
while True:

    next_page = "https://www.yelp.com/biz/monterey-bay-aquarium-monterey?osq=Monterey%20Bay%20Aquarium&start={}".format(index)
    index+=20
    
    page = requests.get(next_page)
    soup = BeautifulSoup(page.content, 'html.parser')
        
    for span in soup.find_all('div',class_="lemon--div__373c0__1mboc u-padding-b2 border-color--default__373c0__2oFDT text-align--center__373c0__1l506"):
        print(span.text)
        
        
    for div in soup.find_all('div',class_='lemon--div__373c0__1mboc arrange-unit__373c0__1piwO arrange-unit-grid-column--8__373c0__2yTAx border-color--default__373c0__2oFDT'):
    #         print(div.text,'\n')


            # Get date for review
            if div.find('span',class_="lemon--span__373c0__3997G text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_"):
                review_date.append(div.find('span',class_="lemon--span__373c0__3997G text__373c0__2pB8f text-color--mid__373c0__3G312 text-align--left__373c0__2pnx_").text)

            # Find 5 star ratings
            if div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-5__373c0__3kPgP border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
                review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-5__373c0__3kPgP border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])

            # Find 4 star ratings
            elif div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-4__373c0__vUL-e border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
                review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-4__373c0__vUL-e border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])


            # Find 3 star ratings
            elif div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-3__373c0__28SvJ border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
                review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-3__373c0__28SvJ border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])


            # Find 2 star ratings
            elif div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-2__373c0__V6RkM border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
                review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-2__373c0__V6RkM border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])


            # Find 1 star ratings              
            elif div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-1__373c0__3Gyy6 border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I"):
                review_rating.append(div.find('div',class_="lemon--div__373c0__1mboc i-stars__373c0__3UQrn i-stars--regular-1__373c0__3Gyy6 border-color--default__373c0__2oFDT overflow--hidden__373c0__8Jq2I")['aria-label'])

            # Get review text
            if div.find('p',class_="lemon--p__373c0__3Qnnj text__373c0__2pB8f comment__373c0__3EKjH text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_"):
                review_text.append(div.find('p',class_="lemon--p__373c0__3Qnnj text__373c0__2pB8f comment__373c0__3EKjH text-color--normal__373c0__K_MKN text-align--left__373c0__2pnx_").text)

    print("Index:",index)
                
    if index >= 4100:
        break
# Out:
# Page 1 of 206
# Page 2 of 206
# Index: 40
# Page 3 of 206
# Index: 60
# Page 4 of 206
# Index: 80
# Page 5 of 206
# Index: 100
# Page 6 of 206
# Index: 120
# Page 7 of 206
# Index: 140
# Page 8 of 206
# Index: 160
# Page 9 of 206
# Index: 180
# Page 10 of 206
# Index: 200
# Page 11 of 206
# Index: 220
# Page 12 of 206
# Index: 240
# Page 13 of 206
# Index: 260
# Page 14 of 206
# Index: 280
# Page 15 of 206
# Index: 300
# Page 16 of 206
# Index: 320
# Page 17 of 206
# Index: 340
# Page 18 of 206
# Index: 360
# Page 19 of 206
# Index: 380
# Page 20 of 206
# Index: 400
# Page 21 of 206
# Index: 420
# Page 22 of 206
# Index: 440
# Page 23 of 206
# Index: 460
# Page 24 of 206
# Index: 480
# Page 25 of 206
# Index: 500
# Page 26 of 206
# Index: 520
# Page 27 of 206
# Index: 540
# Page 28 of 206
# Index: 560
# Page 29 of 206
# Index: 580
# Page 30 of 206
# Index: 600
# Page 31 of 206
# Index: 620
# Page 32 of 206
# Index: 640
# Page 33 of 206
# Index: 660
# Page 34 of 206
# Index: 680
# ...

# %%
data = {'Date': review_date, 'Rating': review_rating, 'Review': review_text}

# %%
len(review_text)
# Out:
# 4100

# %%
len(review_date)
# Out:
# 4100

# %%
len(review_rating)
# Out:
# 4100

# %%
df = pd.DataFrame(data)
df.tail()
# Out:
#             Date         Rating  \
# 4095   1/10/2010  2 star rating
# 4096   3/22/2010  5 star rating
# 4097  10/10/2008  4 star rating
# 4098   2/21/2009  5 star rating
# 4099    6/5/2009  5 star rating
#
#                                                  Review
# 4095  The only part I enjoyed was the sea otters. so...
# 4096  Amazing place for everyone. It might be too cr...
# 4097  Fun Fun Fun many thinggs to do and a lot of th...
# 4098  Just as great as an adult!  As one magazine br...
# 4099  i recently went to the aquarium during spring ...

# %%
df['Rating'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
df['Rating'] = df['Rating'].astype('int32')

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Rating             int32
# Review            object
# dtype: object

# %%
df.sort_values(by='Date')
# Out:
#            Date  Rating                                             Review
# 3242 2005-05-08       5  I can't believe I am the first one to rate thi...
# 3781 2005-05-10       5  I think the world would be a better place if w...
# 3360 2005-05-27       5  This is my favorite aquarium on the West Coast...
# 3927 2005-08-17       5  What a great experience, I only wish I could'v...
# 2517 2005-11-12       4  Loved this place. Generally I get bored very e...
# ...         ...     ...                                                ...
# 7    2020-02-22       5  Got a 2 day pass.  If you don't want to wait i...
# 1    2020-02-25       5  I first came here for a field trip way back in...
# 17   2020-02-28       5  Most exciting place! Education, activities, am...
# 0    2020-02-28       5  Ya know we all went here as a 1st grade field ...
# 19   2020-02-29       4  This is a fun couple of hours for the family. ...
#
# [4100 rows x 3 columns]

# %%
df
# Out:
#            Date  Rating                                             Review
# 0    2020-02-28       5  Ya know we all went here as a 1st grade field ...
# 1    2020-02-25       5  I first came here for a field trip way back in...
# 2    2020-02-20       4  I visited Monterey Bay Aquarium for the first ...
# 3    2020-02-19       3  I came here for my first time in 2005 and it w...
# 4    2020-02-11       5  Great place to go for groups of all ages!  Not...
# ...         ...     ...                                                ...
# 4095 2010-01-10       2  The only part I enjoyed was the sea otters. so...
# 4096 2010-03-22       5  Amazing place for everyone. It might be too cr...
# 4097 2008-10-10       4  Fun Fun Fun many thinggs to do and a lot of th...
# 4098 2009-02-21       5  Just as great as an adult!  As one magazine br...
# 4099 2009-06-05       5  i recently went to the aquarium during spring ...
#
# [4100 rows x 3 columns]

# %%
df.to_csv('file1.csv')
